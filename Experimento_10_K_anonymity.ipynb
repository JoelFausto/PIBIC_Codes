# %% [markdown]
# ### Importando bibliotecas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pycanon
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 37.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 633.2/633.2 kB 47.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 180.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 95.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 97.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 49.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 4.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing_extensions
#     Found existing installation: typing_extensions 4.16.0
#     Uninstalling typing_extensions-4.16.0:
# ...

# %%
import pandas as pd
from collections import Counter
import time
from pycanon import anonymity, report

# %% [markdown]
# ### Dados

# %%
pd.set_option('display.max_columns', None)

# %%
microdados = pd.read_parquet('/content/drive/MyDrive/PIBIC/dadosCenso2018_featuresML.parquet')

# %%
microdados.head()
# Out:
#    index                          ID_ALUNO  IN_FINANCIAMENTO_ESTUDANTIL  \
# 0      0  2ECD7C9BEA7DCEBC31B9F2874D454F71                         -1.0
# 1      1  2A9470AC3FC03AD130954809A84BC7D4                         -1.0
# 2      2  3EA3DF175677D93C4FDD47865E89B92A                         -1.0
# 3      3  E535A93D94430667B67D180C506CCB66                         -1.0
# 4      4  EF1C01E9B84BEB8D6AA9702F59A90410                         -1.0
#
#    IN_DEFICIENCIA  NU_DIA_NASCIMENTO  NU_MES_NASCIMENTO  NU_ANO_NASCIMENTO  \
# 0               9                 30                  9               1992
# 1               9                  8                  6               1987
# 2               9                 13                  1               1988
# 3               9                  3                 10               1988
# 4               9                  8                  4               1977
#
#    TP_SEXO  TP_COR_RACA  CO_MUNICIPIO_NASCIMENTO  TP_NACIONALIDADE  \
# ...

# %% [markdown]
# ### Experimentos - Financiamento Estudantil

# %% [markdown]
# #### Versão Original

# %%
QUASI_IDENTIFICADORES = [
  'NU_DIA_NASCIMENTO', 'NU_MES_NASCIMENTO', 'NU_ANO_NASCIMENTO', 'TP_SEXO', 'TP_COR_RACA',
  'CO_MUNICIPIO_NASCIMENTO', 'TP_NACIONALIDADE', 'CO_PAIS_ORIGEM', 'CO_IES', 'CO_CURSO', 'TP_ESCOLA_CONCLUSAO_ENS_MEDIO'
]
ATRIBUTOS_SENSIVEIS = ["IN_FINANCIAMENTO_ESTUDANTIL"]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# T-Proximidade: 0.5507176041735169

# %% [markdown]
# #### Versão Modificada 1

# %%
QUASI_IDENTIFICADORES = [
    'CO_UF', 'FAIXA_IBGE', 'TP_COR_RACA', 'TP_SEXO',
    'TP_ESCOLA_CONCLUSAO_ENS_MEDIO', 'TP_NACIONALIDADE',
    'CO_PAIS_ORIGEM', 'CO_CINE_AREA_GERAL'
]
ATRIBUTOS_SENSIVEIS = ["IN_FINANCIAMENTO_ESTUDANTIL"]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.5507176041735169

# %% [markdown]
# #### Versão Modificada 2

# %%
QUASI_IDENTIFICADORES = [
    'CO_UF', 'FAIXA_IBGE', 'TP_COR_RACA', 'TP_SEXO',
    'TP_ESCOLA_CONCLUSAO_ENS_MEDIO', 'TP_NACIONALIDADE',
    'CO_PAIS_ORIGEM', 'CO_CINE_ROTULO'
]

ATRIBUTOS_SENSIVEIS = ["IN_FINANCIAMENTO_ESTUDANTIL"]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.5507176041735169

# %% [markdown]
# #### Experimentos

# %%
ATRIBUTOS_SENSIVEIS = ["IN_FINANCIAMENTO_ESTUDANTIL"]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, ['CO_CURSO'])
print(f"K-Anonimato: {k}")
# Out:
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, ['CO_CURSO'], ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, ['CO_CURSO'], ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# T-Proximidade: 0.5507176041735169

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, ['CO_CINE_AREA_GERAL'])
print(f"K-Anonimato: {k}")
# Out:
# K-Anonimato: 40595

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, ['CO_CINE_AREA_GERAL'], ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# L-Diversidade: 3

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, ['CO_CINE_AREA_GERAL'], ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# T-Proximidade: 0.5481803458904771

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, ['CO_CINE_AREA_ESPECIFICA'])
print(f"K-Anonimato: {k}")
# Out:
# K-Anonimato: 265

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, ['CO_CINE_AREA_ESPECIFICA'], ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, ['CO_CINE_AREA_ESPECIFICA'], ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# T-Proximidade: 0.5507176041735169

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, ['CO_CINE_AREA_DETALHADA'])
print(f"K-Anonimato: {k}")
# Out:
# K-Anonimato: 108

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, ['CO_CINE_AREA_DETALHADA'], ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, ['CO_CINE_AREA_DETALHADA'], ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# T-Proximidade: 0.5507176041735169

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, ['CO_CINE_ROTULO'])
print(f"K-Anonimato: {k}")
# Out:
# K-Anonimato: 4

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, ['CO_CINE_ROTULO'], ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, ['CO_CINE_ROTULO'], ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# T-Proximidade: 0.5507176041735169

# %%
QUASI_IDENTIFICADORES = [
  'CO_CURSO', 'FAIXA_IBGE'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.5507176041735169

# %%
QUASI_IDENTIFICADORES = [
  'CO_CINE_AREA_GERAL', 'FAIXA_IBGE'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 5747

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 3

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.5498926454214546

# %%
QUASI_IDENTIFICADORES = [
  'CO_CINE_ROTULO', 'FAIXA_IBGE'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.5507176041735169

# %%
QUASI_IDENTIFICADORES = [
  'CO_CURSO', 'CO_UF'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# T-Proximidade: 0.5507176041735169

# %%
QUASI_IDENTIFICADORES = [
  'CO_CINE_AREA_GERAL', 'CO_UF'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# K-Anonimato: 44

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# T-Proximidade: 0.5507176041735169

# %%
QUASI_IDENTIFICADORES = [
  'CO_CINE_ROTULO', 'CO_UF'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# T-Proximidade: 0.5507176041735169

# %%
QUASI_IDENTIFICADORES = [
  'CO_CURSO', 'CO_UF', 'FAIXA_IBGE'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.5507176041735169

# %%
QUASI_IDENTIFICADORES = [
  'CO_CINE_AREA_GERAL', 'CO_UF', 'FAIXA_IBGE'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 2

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.5507176041735169

# %%
QUASI_IDENTIFICADORES = [
  'CO_CINE_ROTULO', 'CO_UF', 'FAIXA_IBGE'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.5507176041735169

# %%
QUASI_IDENTIFICADORES = [
  'CO_CURSO', 'CO_UF', 'FAIXA_IBGE', 'TP_SEXO'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.5507176041735169

# %%
QUASI_IDENTIFICADORES = [
  'CO_CINE_AREA_GERAL', 'CO_UF', 'FAIXA_IBGE', 'TP_SEXO'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.5507176041735169

# %%
QUASI_IDENTIFICADORES = [
  'CO_CINE_ROTULO', 'CO_UF', 'FAIXA_IBGE', 'TP_SEXO'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.5507176041735169

# %%
QUASI_IDENTIFICADORES = [
 'CO_CURSO', 'CO_UF', 'FAIXA_IBGE', 'TP_SEXO', 'TP_COR_RACA', 'TP_NACIONALIDADE', 'CO_PAIS_ORIGEM', 'TP_ESCOLA_CONCLUSAO_ENS_MEDIO'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.5507176041735169

# %% [markdown]
# ### Experimentos - Deficiência

# %% [markdown]
# #### Versão Original

# %%
QUASI_IDENTIFICADORES = [
  'NU_DIA_NASCIMENTO', 'NU_MES_NASCIMENTO', 'NU_ANO_NASCIMENTO', 'TP_SEXO', 'TP_COR_RACA',
  'CO_MUNICIPIO_NASCIMENTO', 'TP_NACIONALIDADE', 'CO_PAIS_ORIGEM', 'CO_IES', 'CO_CURSO', 'TP_ESCOLA_CONCLUSAO_ENS_MEDIO'
]
ATRIBUTOS_SENSIVEIS = ["IN_DEFICIENCIA"]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")

# %% [markdown]
# #### Versão Modificada 1

# %%
QUASI_IDENTIFICADORES = [
    'CO_UF', 'FAIXA_IBGE', 'TP_COR_RACA', 'TP_SEXO',
    'TP_ESCOLA_CONCLUSAO_ENS_MEDIO', 'TP_NACIONALIDADE',
    'CO_PAIS_ORIGEM', 'CO_CINE_AREA_GERAL'
]
ATRIBUTOS_SENSIVEIS = ["IN_DEFICIENCIA"]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.9428189220079431

# %% [markdown]
# #### Versão Modificada 2

# %%
QUASI_IDENTIFICADORES = [
    'CO_UF', 'FAIXA_IBGE', 'TP_COR_RACA', 'TP_SEXO',
    'TP_ESCOLA_CONCLUSAO_ENS_MEDIO', 'TP_NACIONALIDADE',
    'CO_PAIS_ORIGEM', 'CO_CINE_ROTULO'
]
ATRIBUTOS_SENSIVEIS = ["IN_DEFICIENCIA"]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.9428189220079431

# %% [markdown]
# #### Experimentos

# %%
ATRIBUTOS_SENSIVEIS = ["IN_DEFICIENCIA"]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, ['CO_CURSO'])
print(f"K-Anonimato: {k}")
# Out:
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, ['CO_CURSO'], ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, ['CO_CURSO'], ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# T-Proximidade: 0.9428189220079431

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, ['CO_CINE_AREA_GERAL'])
print(f"K-Anonimato: {k}")
# Out:
# K-Anonimato: 40595

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, ['CO_CINE_AREA_GERAL'], ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# L-Diversidade: 3

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, ['CO_CINE_AREA_GERAL'], ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# T-Proximidade: 0.04777105212680251

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, ['CO_CINE_AREA_ESPECIFICA'])
print(f"K-Anonimato: {k}")
# Out:
# K-Anonimato: 265

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, ['CO_CINE_AREA_ESPECIFICA'], ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# L-Diversidade: 2

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, ['CO_CINE_AREA_ESPECIFICA'], ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# T-Proximidade: 0.16358264515830115

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, ['CO_CINE_AREA_DETALHADA'])
print(f"K-Anonimato: {k}")
# Out:
# K-Anonimato: 108

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, ['CO_CINE_AREA_DETALHADA'], ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, ['CO_CINE_AREA_DETALHADA'], ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# T-Proximidade: 0.43509360011953113

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, ['CO_CINE_ROTULO'])
print(f"K-Anonimato: {k}")
# Out:
# K-Anonimato: 4

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, ['CO_CINE_ROTULO'], ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, ['CO_CINE_ROTULO'], ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# T-Proximidade: 0.9319493567905518

# %%
QUASI_IDENTIFICADORES = [
  'CO_CURSO', 'FAIXA_IBGE'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.9428189220079431

# %%
QUASI_IDENTIFICADORES = [
  'CO_CINE_AREA_GERAL', 'FAIXA_IBGE'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 5747

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 3

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.05255749714264682

# %%
QUASI_IDENTIFICADORES = [
  'CO_CINE_ROTULO', 'FAIXA_IBGE'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.9428189220079431

# %%
QUASI_IDENTIFICADORES = [
  'CO_CURSO', 'CO_UF'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# T-Proximidade: 0.9428189220079431

# %%
QUASI_IDENTIFICADORES = [
  'CO_CINE_AREA_GERAL', 'CO_UF'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# K-Anonimato: 44

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# T-Proximidade: 0.7356538129736752

# %%
QUASI_IDENTIFICADORES = [
  'CO_CINE_ROTULO', 'CO_UF'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# T-Proximidade: 0.9428189220079431

# %%
QUASI_IDENTIFICADORES = [
  'CO_CURSO', 'CO_UF', 'FAIXA_IBGE'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.9428189220079431

# %%
QUASI_IDENTIFICADORES = [
  'CO_CINE_AREA_GERAL', 'CO_UF', 'FAIXA_IBGE'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 2

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.8165489655493074

# %%
QUASI_IDENTIFICADORES = [
  'CO_CINE_ROTULO', 'CO_UF', 'FAIXA_IBGE'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.9428189220079431

# %%
QUASI_IDENTIFICADORES = [
  'CO_CURSO', 'CO_UF', 'FAIXA_IBGE', 'TP_SEXO'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.9428189220079431

# %%
QUASI_IDENTIFICADORES = [
  'CO_CINE_AREA_GERAL', 'CO_UF', 'FAIXA_IBGE', 'TP_SEXO'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.9428189220079431

# %%
QUASI_IDENTIFICADORES = [
  'CO_CINE_ROTULO', 'CO_UF', 'FAIXA_IBGE', 'TP_SEXO'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.9428189220079431

# %%
QUASI_IDENTIFICADORES = [
 'CO_CURSO', 'CO_UF', 'FAIXA_IBGE', 'TP_SEXO', 'TP_COR_RACA', 'TP_NACIONALIDADE', 'CO_PAIS_ORIGEM', 'TP_ESCOLA_CONCLUSAO_ENS_MEDIO'
]

# %%
# 1. K-Anonimato
k = anonymity.k_anonymity(microdados, QUASI_IDENTIFICADORES)
print(f"K-Anonimato: {k}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# K-Anonimato: 1

# %%
# 2. L-Diversidade
l_div = anonymity.l_diversity(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"L-Diversidade: {l_div}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# L-Diversidade: 1

# %%
# 3. T-Proximidade
t_prox = anonymity.t_closeness(microdados, QUASI_IDENTIFICADORES, ATRIBUTOS_SENSIVEIS)
print(f"T-Proximidade: {t_prox}")
# Out:
# /usr/local/lib/python3.12/dist-packages/pycanon/anonymity/utils/aux_anonymity.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_grouped = data.groupby(by=quasi_ident)
# T-Proximidade: 0.9428189220079431
